# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib._color_data as mcd

# %%
df=pd.read_csv(r'C:/Users/Victor/Dropbox/Papers/2019EvolvingAlgorithms/2014EvolvingGROUPS/Paper Grouping/PaperACP Versión 2022/DatosFigura.csv')
df.head(5)
# Out:
#    xj  yj  Cluster
# 0  56 -64        1
# 1  38 -62        1
# 2  38 -48        1
# 3  38 -36        1
# 4  53 -35        1

# %%
x = df['xj']
y = df['yj']
Cluster = df['Cluster']
centers = np.random.randn(1, 2) 

fig = plt.figure(figsize=(14,9))
ax = fig.add_subplot(111)
scatter = ax.scatter(x,y,c=Cluster,s=50)
for i,j in centers:
    ax.scatter(i,j,s=50,c='red',marker='+')
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')
